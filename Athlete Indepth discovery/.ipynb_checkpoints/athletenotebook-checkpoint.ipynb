# %%
import pandas as pd

# %%
athlete_df = pd.read_csv("athletedataset.csv")

# %%
athlete_df.head()
# Out:
#    Unnamed: 0   rcc  wcc    hc    hg  ferr    bmi    ssf  pcBfat    lbm  \
# 0           1  3.96  7.5  37.5  12.3    60  20.56  109.1   19.75  63.32
# 1           2  4.41  8.3  38.2  12.7    68  20.67  102.8   21.30  58.55
# 2           3  4.14  5.0  36.4  11.6    21  21.86  104.6   19.88  55.36
# 3           4  4.11  5.3  37.3  12.6    69  21.88  126.4   23.66  57.18
# 4           5  4.45  6.8  41.5  14.0    29  18.96   80.3   17.64  53.20
#
#       ht    wt sex   sport
# 0  195.9  78.9   f  B_Ball
# 1  189.7  74.4   f  B_Ball
# 2  177.8  69.1   f  B_Ball
# 3  185.0  74.9   f  B_Ball
# 4  184.6  64.6   f  B_Ball

# %%
athlete_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
The name of the data set is the "Australian Athletes Data Set". 
This data set details cetain physical characteristics of austrialian athlete.
# Out:
#   File "<ipython-input-6-62a62bac205d>", line 1
#     The name of the data set is the "Australian Athletes Data Set".
#            ^
# SyntaxError: invalid syntax

# %%
athlete_df
# Out:
#       rcc   wcc    hc    hg  ferr    bmi    ssf  pcBfat    lbm     ht     wt  \
# 0    3.96   7.5  37.5  12.3    60  20.56  109.1   19.75  63.32  195.9   78.9
# 1    4.41   8.3  38.2  12.7    68  20.67  102.8   21.30  58.55  189.7   74.4
# 2    4.14   5.0  36.4  11.6    21  21.86  104.6   19.88  55.36  177.8   69.1
# 3    4.11   5.3  37.3  12.6    69  21.88  126.4   23.66  57.18  185.0   74.9
# 4    4.45   6.8  41.5  14.0    29  18.96   80.3   17.64  53.20  184.6   64.6
# 5    4.10   4.4  37.4  12.5    42  21.04   75.2   15.58  53.77  174.0   63.7
# 6    4.31   5.3  39.6  12.8    73  21.69   87.2   19.99  60.17  186.2   75.2
# 7    4.42   5.7  39.9  13.2    44  20.62   97.9   22.43  48.33  173.8   62.3
# 8    4.30   8.9  41.1  13.5    41  22.64   75.1   17.95  54.57  171.4   66.5
# 9    4.51   4.4  41.6  12.7    44  19.44   65.1   15.07  53.42  179.9   62.9
# 10   4.71   5.3  41.4  14.0    38  25.75  171.1   28.83  68.53  193.4   96.3
# ...

# %%
In this data set there are 202 rows, each row representing one athlete, 
and 13 columns which details the physical attributes of each athlete. There is
a traget label which is the sports column. This target label could be used to 
see the differences in physically attributes between athletes in different sports,
for example: do basketball players tend to be taller than water polo players.

# %%
athlete_df.describe()
# Out:
#               rcc         wcc          hc          hg        ferr         bmi  \
# count  202.000000  202.000000  202.000000  202.000000  202.000000  202.000000
# mean     4.718614    7.108911   43.091584   14.566337   76.876238   22.955891
# std      0.457976    1.800337    3.662989    1.362451   47.501239    2.863933
# min      3.800000    3.300000   35.900000   11.600000    8.000000   16.750000
# 25%      4.372500    5.900000   40.600000   13.500000   41.250000   21.082500
# 50%      4.755000    6.850000   43.500000   14.700000   65.500000   22.720000
# 75%      5.030000    8.275000   45.575000   15.575000   97.000000   24.465000
# max      6.720000   14.300000   59.700000   19.200000  234.000000   34.420000
#
#               ssf      pcBfat         lbm          ht          wt
# count  202.000000  202.000000  202.000000  202.000000  202.000000
# mean    69.021782   13.507426   64.873713  180.103960   75.007921
# std     32.565333    6.189826   13.070197    9.734494   13.925199
# ...

# %%
Nearly all of the rows are numerical, as almost all of the rows describe the attributes
of the athletes. There are two exceptions how ever, the gender of the athlete and
the sport that the athlete is playing are both catagorical.

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.set()

# %%
sns.distplot(athlete_df.loc[:,'ht'], hist=True, kde=True, bins=None)

# %%
sns.distplot(athlete_df.loc[:,'wt'], hist=True, kde=True, bins=None)

# %%
sns.distplot(athlete_df.loc[:,'pcBfat'], hist=True, kde=True, bins=None)

# %%
sns.distplot(athlete_df.loc[:,'bmi'], hist=True, kde=True, bins=None)

# %%
sns.countplot(athlete_df.loc[:,'sport'])

# %%
sns.pairplot(athlete_df, hue='sport', size=3, vars=["ht", "wt"])

# %%
I am chosing to alanysis this data set so that I can identify the differences in 
physical characteristics in athelets for different sports. As well as detemine
what values for those attributes are most common so that I can identify basic 
requirements for each sport. And I can Idenifty which sport I would be a best fit 
for based off of my physical attributes. I am going to build models that look 
mostly at height, weight, body mass index, and percent body fat in relation to the
sport that the athlete plays. This will hopefully help me answer the questions I 
have set out to answer by chosing this data set. I except to see results for those 
physical attributes to be much greater than the average person. I also except to 
see minor difference in those attributes in most sport, but a few sports to have
great differences for example basketball players will be alot taller than average.
I would also expect there to be a skew towards heavier people because bigger people
make better athletes .

# %%
The graphs below detail the average and spread of the weight, height, percent body fat, and bmi for the Australian athletes.

# %%
The graph below details the average weight for males and females in each sport.

# %%
sns.barplot(x='sport', y = 'wt', hue = 'sex', data = athlete_df)

# %%
As shown by the data field athletes tend to way the most of all of the sports 95kg for male and 80kg for females.
This would make sense because field involvesmostly throwing so being heavier would make throw those objects easier.
Furthermore, Track athletes who run the 400m dash are the lightest athletes with an average of 65kg for males and 58 kg for 
females. These results should also be expected because 400m is long enought that less weight would benefit the runner. A result
that supprised me was the average weight of rowers, about 85kg for males and about 70kg for females. In relation to the other 
sports rowing has around the third heaviest athletes. I thought that being lighter would be beneficial because it would take less
force for the boat to travel the same speed.

# %%
The graph below illustrates the weight distribution of australian athletes.

# %%
sns.boxplot(x='sport', y = 'wt', hue = 'sex', data = athlete_df)

# %%
One of the most telling results in this analytic is the weight spread of tennis male athletes. The weight range is only around
10kg suggesting that their is a very strict threshold for weight to be a tennis athlete. This could be because a taller frame 
would allow the player to have a greater reach towards the ball making the minimum weight 75kg, but any more weight would result
in a decrease in the quick movement speed required to chase the tennis ball resulting in a max weight of 80kg.

# %%
The graph below depicts average height of male and female austrailian athletes for different sports.

# %%
import matplotlib.pyplot as plt
plt.ylim(150, 205)
sns.barplot(x='sport', y = 'ht', hue = 'sex', data = athlete_df)

# %%
The sport has the tallest athletes on average is basket ball with an average height of 195 cm, only leaving around 110 cm to go
to get the the rim of the basketball hoop. Sprinters are the shortest atlethes on average, just under 180 cm. This means that 
spriting favors a smaller frame with a decent amount of weight probably as muscle so that the athletes can have the explosive 
speed and acceleration need to sprint that distance. Another result that was supprising is water polo being the second tallest 
combine this with also tied for the second heaviest athletes, there are big people playing water polo which seems like it could 
be tough because of all of the water treading involved in that sport. I except water polo athletes to have a high body fat
percentage to help them float and take some of the strain off of the constant treading. It is worth noting that women athletes
seems to have a smaller differential between of height between sports than men do. There is about a 12 cm difference between the 
tallest average and the shortest average for women, and about and 18 cm difference between the shortest and the tallest sports 
for men.

# %%
The graph below illustrates the distribuiton of height for men and women in different sports.

# %%
sns.boxplot(x='sport', y = 'ht', hue = 'sex', data = athlete_df)

# %%
One of the most intesting results form this analytic comes from the male swim athletes. Male swim athletes have a second and 
fourth quartile that span around only 2 cm each, while the first and thrid quartile each span around 10 cms. This result leaves
me puzzled on what the cause would be. My best guess is that there are two specific heights in which are extremely beneficial for
certine swim strokes. Another results that explifies meaning full data is the female rowing athletes and the male tennis athletes.
for the male tennis athletes they already had one of the smallest spreads for weight and once again in height basically all
of the athletes are within 7 cms of each other with only one outlire. This shows that to be a tennis athlete you need a very
specific body type that can have very little variation. As for female rowing there is alot of concentrated height around the 180
cm mark and then an outlire all the way down at around the 155 cm mark. I believe this could be the result of the coxswain whose
job it is to tell the rowers when to row and not row themselves. For this position the smaller the person the faster the 
boat would go.

# %%
The bar graph below details average percent body fat of males and females for different sports.

# %%
sns.barplot(x='sport', y = 'pcBfat', hue = 'sex', data = athlete_df)

# %%
This analytic shows that water polo player do indeed have the highest body fat percentage. Which I predicted would be the case so
that they could float easier and use less energy trying to paddle. Another instresting detail is that womens 
netball has the highest percent body fat, even a few percentage points over womens field. I do not know why that would be the 
case. Once again field has one of the highest average values, so inorder to be a field athlete you need to be on the bigger 
side. And Both sprinting sports have the lowest body fat compsition so to be a sprint you need to be tall but not to tall
and have an average amount of weight, but have that weight be all muscle. Something worth noting too is that women who go to
the gym had a lower percent body fat than most of the athletes on sports team. So if someone is looking to shave off a few 
pounds of fat it would appear to be more efficient to go to the gym than join a sports team.

# %%
sns.boxplot(x='sport', y = 'pcBfat', hue = 'sex', data = athlete_df)

# %%
The most interesting stat in this analytic is the percentage body fat for womens netball. The spread ranges from about 12% to 37%
and it is has an even spread for each quartile. To get more backround knowledge on why this might be happening. It could be 
because net ball is a less known sport and the athletes are on club teams that would be less comptetive than other more 
popular sports like basketball and tennis.

# %%
The graph below illustrates the body mass index for females and males in different sports.

# %%
sns.barplot(x='sport', y = 'bmi', hue = 'sex', data = athlete_df)

# %%
Body mass index is a ratio of height to weight. According to this analytic Athletes who run the 400 meter dash are typically the
skinniest people while field athletes are the have a more fulled out stature. Once again if the average person is looking to have
a skinnier figure going to the gym appears to be a better option then joining a sports team.

# %%
sns.boxplot(x='sport', y = 'bmi', hue = 'sex', data = athlete_df)

# %%
In summary, evey sport has a basic body struture that is favored. For example, basketball favors much taller and skinner 
athletes, while sprinters are smaller in height but still to have a high bmi with almost all of that weight as muscle. 
Some sports also have a much greater leniecy for physical builds. While feild has a very large range of body stucture, sports
like tennis are so strict that even 7 kgs can make or break and athlete. There also sports that have significant
outlires or are multimodal. This can usually be attributed to different position in that sport like rowwing which has rowers
and coxswains or swimming which can have different events that favor differnt body styles. Overall there seems to a be a few
minimum values that a person must meet to be an athlete of any sport which is about 75 kg for males and 63 kg for females.
The average weight for a man 20-29 years old is 84 kgs about 75 kg for females (according to Erin Coleman from livestrong.com).
The minimum height for the american mqn is around 180 cm and around 170 cm for females, this is around 3 cm taller than
the average formen according to halls.md and around 7 cm taller than women. So the good news for the average american man
is they are not too far from being an athlete, women have a little further to go. Personally, I am around 177.5 cm tall, I
weigh 63.5 kgs, I have around a 17% body fat, and a 20.4 bmi. So the sport that would fit me the best a 400 meter sprinter. 
I did run the 400 meter dash a few times in high school and I was both very bad at it and hated doing it, but I did guess 
the right sport for me stature wise at the time.
